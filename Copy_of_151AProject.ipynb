# %% [markdown]
# <a href="https://colab.research.google.com/github/Sherif-Elfiky/CSE151AProj/blob/main/Copy_of_151AProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/Sherif-Elfiky/CSE151AProj.git
# Out:
# fatal: destination path 'CSE151AProj' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('CSE151AProj/historical_data.csv')
data
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2             3.0  2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3             3.0  2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4             3.0  2015-02-15 02:40:36  2015-02-15 03:20:26      5477
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %% [markdown]
# **Convert String times to actual times**

# %%
data['created_at'] = pd.to_datetime(data['created_at'])
data['actual_delivery_time'] = pd.to_datetime(data['actual_delivery_time'])

# %%
data
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2             3.0  2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3             3.0  2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4             3.0  2015-02-15 02:40:36  2015-02-15 03:20:26      5477
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
data['delivery time'] = pd.to_datetime(data['actual_delivery_time']) - pd.to_datetime(data['created_at'])

# %%
data
# Out:
#         market_id          created_at actual_delivery_time  store_id  \
# 0             1.0 2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0 2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2             3.0 2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3             3.0 2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4             3.0 2015-02-15 02:40:36  2015-02-15 03:20:26      5477
# ...           ...                 ...                  ...       ...
# 197423        1.0 2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0 2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0 2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0 2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0 2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
data = data.drop(columns=['actual_delivery_time', 'created_at', 'store_primary_category'])

# %%
sns.heatmap(data.corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <Axes: >
